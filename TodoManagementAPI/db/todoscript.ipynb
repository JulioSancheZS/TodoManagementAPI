-- %% [markdown]
-- # [TodoManagementAPI]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [TodoManagementAPI]    Script Date: 28/1/2024 21:55:04 ******/
CREATE DATABASE [TodoManagementAPI]
 CONTAINMENT = NONE
 ON  PRIMARY 
go
ALTER DATABASE [TodoManagementAPI] SET COMPATIBILITY_LEVEL = 140
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [TodoManagementAPI].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [TodoManagementAPI] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET ARITHABORT OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [TodoManagementAPI] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [TodoManagementAPI] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET  DISABLE_BROKER 
GO
ALTER DATABASE [TodoManagementAPI] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [TodoManagementAPI] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [TodoManagementAPI] SET  MULTI_USER 
GO
ALTER DATABASE [TodoManagementAPI] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [TodoManagementAPI] SET DB_CHAINING OFF 
GO
ALTER DATABASE [TodoManagementAPI] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [TodoManagementAPI] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [TodoManagementAPI] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [TodoManagementAPI] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[EstadoTarea]

-- %%
USE [TodoManagementAPI]
GO

-- %%
/****** Object:  Table [dbo].[EstadoTarea]    Script Date: 28/1/2024 21:55:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EstadoTarea](
	[IdEstado] [int] IDENTITY(1,1) NOT NULL,
	[Description] [nvarchar](50) NULL,
 CONSTRAINT [PK_EstadoTarea] PRIMARY KEY CLUSTERED 
(
	[IdEstado] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tarea]

-- %%
/****** Object:  Table [dbo].[Tarea]    Script Date: 28/1/2024 21:55:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tarea](
	[IdTarea] [int] IDENTITY(1,1) NOT NULL,
	[Titulo] [nvarchar](100) NULL,
	[Descripcion] [nvarchar](100) NULL,
	[IdEstadoTarea] [int] NULL,
	[IdUsuario] [int] NULL,
 CONSTRAINT [PK_Tarea] PRIMARY KEY CLUSTERED 
(
	[IdTarea] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 28/1/2024 21:55:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[IdUsuario] [int] IDENTITY(1,1) NOT NULL,
	[Usuario] [nvarchar](50) NULL,
	[Password] [nvarchar](50) NULL,
	[Correo] [nvarchar](100) NULL,
	[PrimerNombre] [nvarchar](100) NULL,
	[PrimerApellido] [nvarchar](100) NULL,
 CONSTRAINT [PK_Usuario] PRIMARY KEY CLUSTERED 
(
	[IdUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Tarea_EstadoTarea]

-- %%
ALTER TABLE [dbo].[Tarea]  WITH CHECK ADD  CONSTRAINT [FK_Tarea_EstadoTarea] FOREIGN KEY([IdEstadoTarea])
REFERENCES [dbo].[EstadoTarea] ([IdEstado])
GO
ALTER TABLE [dbo].[Tarea] CHECK CONSTRAINT [FK_Tarea_EstadoTarea]
GO

-- %% [markdown]
-- # [FK_Tarea_Usuario]

-- %%
ALTER TABLE [dbo].[Tarea]  WITH CHECK ADD  CONSTRAINT [FK_Tarea_Usuario] FOREIGN KEY([IdUsuario])
REFERENCES [dbo].[Usuario] ([IdUsuario])
GO
ALTER TABLE [dbo].[Tarea] CHECK CONSTRAINT [FK_Tarea_Usuario]
GO

-- %% [markdown]
-- # [TodoManagementAPI]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [TodoManagementAPI] SET  READ_WRITE 
GO
